# %%
import pandas as pd

# %%
df=pd.read_csv("TotalQuantityByHour.csv")

# %%
newdf = df[9497:]
newdf
# Out:
#                InvoiceDate  Quantity
# 9497   2011-01-01 00:00:00         0
# 9498   2011-01-01 01:00:00         0
# 9499   2011-01-01 02:00:00         0
# 9500   2011-01-01 03:00:00         0
# 9501   2011-01-01 04:00:00         0
# 9502   2011-01-01 05:00:00         0
# 9503   2011-01-01 06:00:00         0
# 9504   2011-01-01 07:00:00         0
# 9505   2011-01-01 08:00:00         0
# 9506   2011-01-01 09:00:00         0
# 9507   2011-01-01 10:00:00         0
# 9508   2011-01-01 11:00:00         0
# 9509   2011-01-01 12:00:00         0
# 9510   2011-01-01 13:00:00         0
# 9511   2011-01-01 14:00:00         0
# 9512   2011-01-01 15:00:00         0
# 9513   2011-01-01 16:00:00         0
# 9514   2011-01-01 17:00:00         0
# 9515   2011-01-01 18:00:00         0
# 9516   2011-01-01 19:00:00         0
# 9517   2011-01-01 20:00:00         0
# 9518   2011-01-01 21:00:00         0
# 9519   2011-01-01 22:00:00         0
# 9520   2011-01-01 23:00:00         0
# ...

# %%
newdf['Quantity'].min()
# Out:
# -27322

# %%
newdf2=newdf.replace(to_replace =-27322, 
                 value =0) 
newdf2['Quantity'].min()
# Out:
# -14899

# %%
newdf3=newdf2.replace(to_replace =-14899, 
                 value =0) 
newdf3['Quantity'].min()
# Out:
# -6915

# %%
newdf3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8221 entries, 9497 to 17717
# Data columns (total 2 columns):
# InvoiceDate    8221 non-null object
# Quantity       8221 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 128.5+ KB

# %%
newdf3.describe()
# Out:
#            Quantity
# count   8221.000000
# mean     450.990755
# std     1098.906952
# min    -6915.000000
# 25%        0.000000
# 50%        0.000000
# 75%      399.000000
# max    15012.000000

# %%
newdf3.to_csv(r'C:\Users\dell\Desktop\newdf3.csv')
